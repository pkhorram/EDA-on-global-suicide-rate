# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import customfunctions as cf

# %%
df = pd.read_csv('./master.csv')

print('The number of training examples before preprocess: ', len(df))
new_df = cf.preprocess(df)
print('The number of training examples after preprocess: ', len(new_df))
new_df.head()
# Out:
# The number of training examples before preprocess:  27820
# The number of training examples after preprocess:  27660
#   continent  country  year     sex          age  suicides_no  population  \
# 0    Europe  Albania  1987    male  15-24 years           21      312900
# 1    Europe  Albania  1987    male  35-54 years           16      308000
# 2    Europe  Albania  1987  female  15-24 years           14      289700
# 3    Europe  Albania  1987    male    75+ years            1       21800
# 4    Europe  Albania  1987    male  25-34 years            9      274300
#
#    suicides_per_100k country-year  gdp_for_year ($)   gdp_per_capita ($)  \
# 0               6.71  Albania1987      2,156,624,900                 796
# 1               5.19  Albania1987      2,156,624,900                 796
# 2               4.83  Albania1987      2,156,624,900                 796
# 3               4.59  Albania1987      2,156,624,900                 796
# ...

# %%
cf.suiciderate_gender_year(new_df)
cf.suicidecount_gender_year(new_df)

# %%
cf.suiciderate_gdp_gender(new_df, 'United States')
cf.suicidecount_gdp_gender(new_df, 'United States')

# %%
cf.suiciderate_age_year(new_df)

# %%
cf.suiciderate_age(new_df)
cf.suicidecount_age(new_df)

# %%
cf.suiciderate_cont_time(new_df)

# %%
cf.suicides_cont_avg(new_df)
# Out:
# Continent: Europe
#  Highest rate: [{'Lithuania': 487.00761904761913}]
#  Lowest rate: [{'Albania': 42.03454545454546}]
# Continent: Americas
#  Highest rate: [{'Guyana': 266.2368}]
#  Lowest rate: [{'Jamaica': 6.261176470588234}]
# Continent: Asia
#  Highest rate: [{'Sri Lanka': 423.54181818181826}]
#  Lowest rate: [{'Oman': 8.833333333333334}]
# Continent: Oceania
#  Highest rate: [{'New Zealand': 172.7006896551724}]
#  Lowest rate: [{'Fiji': 61.26}]
# Continent: Africa
#  Highest rate: [{'Mauritius': 140.81548387096774}]
#  Lowest rate: [{'South Africa': 11.5745}]

# %%
cf.suiciderate_country_time(new_df,['Lithuania', 'Russian Federation', 'Albania'])
